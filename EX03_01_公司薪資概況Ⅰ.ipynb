# %% [markdown]
# <a href="https://colab.research.google.com/github/yunhsuan1009/yunhsuan/blob/main/EX03_01_%E5%85%AC%E5%8F%B8%E8%96%AA%E8%B3%87%E6%A6%82%E6%B3%81%E2%85%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# 宣告建立一維資料 Series
age = [25, 30, 35, 40, 22, 29, 38, 27, 33, 31]
se = pd.Series(age)
se
# Out:
# 0    25
# 1    30
# 2    35
# 3    40
# 4    22
# 5    29
# 6    38
# 7    27
# 8    33
# 9    31
# dtype: int64

# %%
se.values
se.index
se.dtype
# Out:
# dtype('int64')

# %%
# 自訂索引
name = ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Helen', 'Ivy', 'Jack']
age = [25, 30, 35, 40, 22, 29, 38, 27, 33, 31]
seidx = pd.Series(age, index=name)
seidx
# Out:
# Alice      25
# Bob        30
# Charlie    35
# David      40
# Eve        22
# Frank      29
# Grace      38
# Helen      27
# Ivy        33
# Jack       31
# dtype: int64

# %%
import pandas as pd

data = {
    'ID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Helen', 'Ivy', 'Jack'],
    'Age': [25, 30, 35, 40, 22, 29, 38, 27, 33, 31],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix', 'Philadelphia', 'San Antonio', 'San Diego', 'Dallas', 'San Jose'],
    'Salary': [50000, 60000, 75000, 80000, 45000, 62000, 72000, 58000, 69000, 71000],
    'Department': ['IT', 'HR', 'Finance', 'Marketing', 'IT', 'HR', 'Finance', 'Marketing', 'IT', 'Finance']
}
df = pd.DataFrame(data)
df
# Out:
#     ID     Name  Age          City  Salary Department
# 0  101    Alice   25      New York   50000         IT
# 1  102      Bob   30   Los Angeles   60000         HR
# 2  103  Charlie   35       Chicago   75000    Finance
# 3  104    David   40       Houston   80000  Marketing
# 4  105      Eve   22       Phoenix   45000         IT
# 5  106    Frank   29  Philadelphia   62000         HR
# 6  107    Grace   38   San Antonio   72000    Finance
# 7  108    Helen   27     San Diego   58000  Marketing
# 8  109      Ivy   33        Dallas   69000         IT
# 9  110     Jack   31      San Jose   71000    Finance

# %% [markdown]
# 使用上述字典資料建立 Pandas Dataframe，並進行以下的分析操作：
# 取得 Name 和 Salary 二欄資料
# 取出索引值 5 到 8 共 4 筆資料
# 找出年齡和薪水都高於平均值的人員
# 請問公司人員的平均薪水、及最高、最低薪水、中位數？
# 公司共有幾個部門？那個部門薪水最高？那個部門最年輕？
# 年齡是否與薪資有關？

# %% [markdown]
# 取得name和salary二欄資料

# %%
df[['Name','Salary']]
# Out:
#       Name  Salary
# 0    Alice   50000
# 1      Bob   60000
# 2  Charlie   75000
# 3    David   80000
# 4      Eve   45000
# 5    Frank   62000
# 6    Grace   72000
# 7    Helen   58000
# 8      Ivy   69000
# 9     Jack   71000

# %% [markdown]
# 取出索引值 5 到 8 共 4 筆資料

# %%
df.loc[5:8]
# Out:
#     ID   Name  Age          City  Salary Department
# 5  106  Frank   29  Philadelphia   62000         HR
# 6  107  Grace   38   San Antonio   72000    Finance
# 7  108  Helen   27     San Diego   58000  Marketing
# 8  109    Ivy   33        Dallas   69000         IT

# %%
df.iloc[5:9]
# Out:
#     ID   Name  Age          City  Salary Department
# 5  106  Frank   29  Philadelphia   62000         HR
# 6  107  Grace   38   San Antonio   72000    Finance
# 7  108  Helen   27     San Diego   58000  Marketing
# 8  109    Ivy   33        Dallas   69000         IT

# %% [markdown]
# 找出年齡和薪水都高於平均值的人員

# %%
avg_age = df['Age'].mean()
avg_salary = df['Salary'].mean()
df[(df['Age'] > avg_age) & (df['Salary'] > avg_salary)]
# Out:
#     ID     Name  Age         City  Salary Department
# 2  103  Charlie   35      Chicago   75000    Finance
# 3  104    David   40      Houston   80000  Marketing
# 6  107    Grace   38  San Antonio   72000    Finance
# 8  109      Ivy   33       Dallas   69000         IT

# %% [markdown]
# 請問公司人員的平均薪水、及最高、最低薪水、中位數

# %%
print(df['Salary'].mean(),df['Salary'].max(),df['Salary'].min(),df['Salary'].median())
# Out:
# 64200.0 80000 45000 65500.0

# %% [markdown]
# 公司共有幾個部門？

# %%
df['Department'].unique
# Out:
# array(['IT', 'HR', 'Finance', 'Marketing'], dtype=object)

# %% [markdown]
# 那個部門薪水最高

# %%
print( df.groupby('Department')['Salary'].mean().idxmax(),df.groupby('Department')['Salary'].mean().max() )
# Out:
# Finance 72666.66666666667

# %% [markdown]
# 那個部門最年輕？

# %%
print( df.groupby('Department')['Age'].mean().idxmax(),df.groupby('Department')['Age'].mean().max() )
# Out:
# Finance 34.666666666666664

# %% [markdown]
# 年齡是否與薪資有關？答:是，推測為年齡越大者，求職經驗較豐富公司也更願意以較高薪資聘請。

# %%
corr_matrix = df[['Age', 'Salary']].corr()
corr_matrix
# Out:
#              Age    Salary
# Age     1.000000  0.949344
# Salary  0.949344  1.000000
